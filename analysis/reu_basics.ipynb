# %% [markdown]
# # Data Analysis with Python
#
# Today we will look at two things:
# 1. Regression analysis with scikit-learn.
# 2. Neural networks in PyTorch.

# %%
import sys

# %% [markdown]
# ## Section 1: Regression in scikit-learn

# %%
import pandas as pd
import numpy as np
#np.set_printoptions(threshold=sys.maxsize)

import matplotlib.pyplot as plt
import matplotlib as mpl
#mpl.rcParams['figure.dpi'] = 300
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# We will be looking at [Data on Energy](https://github.com/owid/energy-data?tab=readme-ov-file) by [Our World in Data](https://ourworldindata.org).

# %%
dat_src = pd.read_csv("https://nyc3.digitaloceanspaces.com/owid-public/data/energy/owid-energy-data.csv")

# %% [markdown]
# The pandas.head function returns a bunch of NaNs so I returned some rows further down to give an idea of the data. Look at the [data dictionary](https://github.com/owid/energy-data/blob/master/owid-energy-codebook.csv) for a more descriptive explanation of the columns.

# %%
#dat_src = dat_src.astype({"year": int})
dat_src.shape
# Out:
# (21812, 129)

# %% [markdown]
# We will subset into annual data from the US and [BRICS](https://en.wikipedia.org/wiki/BRICS) countries since 2000. We will put our focus on major energy types to evaluate any association between population and GDP with adoption of low carbon energy.

# %%
countries = ["United States", "Brazil", "Russia", "India", "China", "South Africa"]
variables = [
      "country",
      "year",
      "population",
      "gdp",
      "electricity_demand",
      "electricity_generation",
      "low_carbon_consumption",
      "low_carbon_electricity",
    ]
dat = dat_src[dat_src["country"].isin(countries) & (dat_src["year"] >= 2000)].loc[:, variables]
dat.shape
# Out:
# (144, 8)

# %%
dat
# Out:
#              country  year   population           gdp  electricity_demand  \
# 3037          Brazil  2000  175873712.0  1.739728e+12              391.92
# 3038          Brazil  2001  178211888.0  1.785513e+12              366.40
# 3039          Brazil  2002  180476688.0  1.861742e+12              382.28
# 3040          Brazil  2003  182629280.0  1.904933e+12              402.58
# 3041          Brazil  2004  184722048.0  2.038448e+12              424.87
# ...              ...   ...          ...           ...                 ...
# 20488  United States  2019  334319680.0  1.854055e+13             4197.42
# 20489  United States  2020  335942016.0  1.802736e+13             4090.49
# 20490  United States  2021  336997632.0  1.909938e+13             4192.93
# 20491  United States  2022  338289856.0  1.949317e+13             4328.12
# 20492  United States  2023  339996576.0           NaN             4266.69
#
#        electricity_generation  low_carbon_consumption  low_carbon_electricity
# 3037                   348.93                1017.443                  318.31
# 3038                   328.55                 926.510                  291.21
# 3039                   345.72                 983.053                  310.26
# 3040                   364.39                1034.508                  330.98
# 3041                   387.49                1077.610                  344.99
# ...                       ...                     ...                     ...
# 20488                 4158.38                4630.352                 1570.17
# 20489                 4043.18                4685.649                 1611.28
# 20490                 4153.62                4786.699                 1641.23
# 20491                 4286.91                5024.875                 1729.69
# 20492                 4249.05                5086.998                 1738.73
#
# [144 rows x 8 columns]

# %%
# generate figure
plt.figure()

# loop over all countries
for country in countries:
  dat_plt = dat[(dat["country"] == country)]
  plt.plot(dat_plt["year"], dat_plt["low_carbon_consumption"], label=country)

# stuff to make it pretty
plt.xlabel("Year")
plt.ylabel("Clean Energy Consumption (TWh)")
plt.title("US & BRICS Clean Energy Consumption")
plt.legend(loc="upper left")
plt.grid(zorder=0, linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# Now let's see if there is a relationship between low carbon (i.e., "clean") energy consumption and GDP. We will need to normalize both per capita. Go ahead and create both variables now. Reminder energy use is reported as TWh and we would like to keep it at kWh when reporting per capita (i.e., multiply by `1e9`).

# %%
### TODO
dat["gdp_per_capita"] = dat["gdp"] / dat["population"]
dat["ceu_per_capita"] = dat["low_carbon_consumption"] / dat["population"] * 1e9

# %% [markdown]
# Let's re-create the plot above but showing how the clean energy consumption varies as a function of GDP per capita. You can copy-and-paste the code (or we encourage you to use your own). If you copy the above you'll need to switch the function from `plt.plot` to `plt.scatter`.

# %%
### TODO

# generate figure
plt.figure()

# loop over all countries
for country in countries:
  dat_plt = dat[(dat["country"] == country)]
  plt.scatter(dat_plt["gdp_per_capita"], dat_plt["ceu_per_capita"], label=country)

# stuff to make it pretty
plt.xlabel("GDP ($)")
plt.ylabel("Clean Energy Consumption (kWh)")
plt.title("US & BRICS Clean Energy Consumption vs GDP per Capita")
plt.legend(loc="upper left")
plt.grid(zorder=0, linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# What do we notice? Let's analyze and quantify the linear relationship of the amount of clean energy consumption as a function of GDP per capita in the US. In the scikit-learn library there is a [linear regression](https://scikit-learn.org/stable/modules/linear_model.html) model function.
#
# $\hat{y} = \beta_0 + \sum \beta_i X_i + ϵ$

# %%
#x_train = dat_train.loc[:, "gdp_per_capita"]
#x_train = x_train.fillna(x_train.median())
#x_train = np.array(x_train).reshape(-1, 1)
#x_train.shape

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score

dat_train = dat[dat["country"] == "United States"]

# clean x
x_train = dat_train.loc[:, "gdp_per_capita"]
x_train = x_train.fillna(x_train.median())
x_train = np.array(x_train).reshape(-1, 1)

# clean y
y_train = dat_train.loc[:, "ceu_per_capita"]
y_train = y_train.fillna(y_train.median())
y_train = np.array(y_train).reshape(-1, 1)

glm = linear_model.LinearRegression()
glm.fit(x_train, y_train)

y_predict = glm.predict(x_train)

# The coefficients
print("Slope: %.2f" % glm.coef_[0][0])
print("Intercept: %.2f" % glm.intercept_[0])
print("R2: %.2f" % r2_score(y_train, y_predict)) # 1 is perfect prediction
# Out:
# Slope: 0.28
# Intercept: -1799.32
# R2: 0.66

# %% [markdown]
# Now let's visualize this and overlay it on top of the observed data points. You can create a range of $X$ values (e.g., [`np.arange`](https://numpy.org/doc/stable/reference/generated/numpy.arange.html)) then feed it into your model to get its predicted outcome and line plot that. Alternatively you can use the slope and intercept and plot a line that way (e.g., [`plt.axline`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axline.html)).

# %%
x_predict = np.expand_dims(np.arange(40000, 80000, 10000), axis=1)
y_predict = glm.predict(x_predict)

# generate figure
plt.figure()

plt.scatter(x_train, y_train, label="United States")
plt.plot(x_predict, y_predict, color="blue", linewidth=2)

# stuff to make it pretty
plt.xlabel("GDP ($)")
plt.ylabel("Clean Energy Consumption (kWh)")
plt.title("US Clean Energy Consumption vs GDP")
#plt.legend(loc="upper left")
plt.grid(zorder=0, linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# Now let's look at a binary outcome and model that versus a numerical feature input. Specifically, let's see if we can use logistic regression to identify an energy independent (i.e., net energy exporting) country from an energy dependent (i.e., net energy importing) country. The classification variable is `Net electricity imports as a share of demand - Electricity imports minus exports, measured as a percentage of total electricity demand.` so 100% implies a full net importer of energy needs and -100% implies a full net exporter of energy.

# %%
variables = [
      "net_elec_imports_share_demand",
      "population",
      "gdp",
      "biofuel_cons_per_capita",
      #"coal_cons_per_capita",
      #"gas_energy_per_capita",
      "hydro_energy_per_capita",
      "nuclear_energy_per_capita",
      #"oil_energy_per_capita",
      "solar_energy_per_capita",
      "wind_energy_per_capita",
    ]
dat = dat_src.loc[:, variables]
dat = dat.dropna()

dat["gdp_per_capita"] = dat["gdp"] / dat["population"]

dat.shape
# Out:
# (1437, 9)

# %%
dat.head()
# Out:
#       net_elec_imports_share_demand  population           gdp  \
# 1122                          6.389  41100124.0  7.857852e+11
# 1123                          6.949  41520736.0  8.377427e+11
# 1124                          5.298  41952364.0  8.291474e+11
# 1125                          5.464  42388268.0  8.490883e+11
# 1126                          6.644  42824064.0  8.277508e+11
#
#       biofuel_cons_per_capita  hydro_energy_per_capita  \
# 1122                  144.122                 2252.866
# 1123                  208.889                 2072.072
# 1124                  247.831                 1906.136
# 1125                  280.795                 2107.085
# 1126                  324.379                 2050.716
#
#       nuclear_energy_per_capita  solar_energy_per_capita  \
# 1122                    467.234                    0.006
# 1123                    408.038                    0.107
# 1124                    401.518                    0.534
# 1125                    382.964                    0.969
# 1126                    334.728                    1.009
#
#       wind_energy_per_capita  gdp_per_capita
# 1122                   1.712    19118.802651
# 1123                   1.767    20176.489413
# 1124                  24.174    19764.022054
# 1125                  29.149    20031.211187
# 1126                  39.190    19329.104533

# %%
y = np.array(dat["net_elec_imports_share_demand"])
print([
    y.mean(),
    np.median(y),
    y.std(),
    y.min(),
    y.max(),
])
# Out:
# [3.3689791231732777, 0.0, 17.57927294000173, -76.715, 93.919]

# %% [markdown]
# ![logit.png](data:image/png;base64,...)

# %% [markdown]
# Logistic regression is similar in form but has a logit function applied to the output to get the shape above on the right.
#
# $\ln \left( \frac{p(x)}{1-p(x)} \right) = \beta_0 + \sum \beta_i X_i + ϵ$
#
# Now let's clean up the data and use the [`LogisticRegression`](https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression) function in scikit-learn. Typically to test the performance of your classifier you want to hold out a subset of your data to evaluate the classifier's performance. The use of the [`train_test_split`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) function makes this easy.

# %%
from sklearn.model_selection import train_test_split

# clean y
y = np.where(dat["net_elec_imports_share_demand"] > 0, 1, 0)
#y = y.reshape(-1, 1)

# clean x
X = dat.iloc[:, 3:]

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=1, shuffle=True)
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (1005, 6)
# y_train: (1005,)
# X_test: (432, 6)
# y_test: (432,)

# %% [markdown]
# The next part is the actual application of the regression. The $\beta$ coefficients associated with each feature are displayed.

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(random_state=0).fit(X_train, y_train)

for i, var in enumerate(X_train.columns):
  print("%s: %.32f" % (var, np.exp(clf.coef_[0, i])))

y_pred = clf.predict(X_test)
# Out:
# biofuel_cons_per_capita: 1.00308718296364740574233564984752
# hydro_energy_per_capita: 0.99995306617477486277323350805091
# nuclear_energy_per_capita: 0.99989069776835715064322585021728
# solar_energy_per_capita: 0.99851254403989098129557078209473
# wind_energy_per_capita: 0.99985814685692264713878785187262
# gdp_per_capita: 1.00001369185615374135522870346904

# %% [markdown]
# ![tpr.png](data:image/png;base64,...)

# %% [markdown]
# $\text{Precision} = \frac{TP}{TP+FP}$ or $\text{Recall} = \frac{TP}{TP+FN}$

# %%
from sklearn import metrics

print(
    metrics.classification_report(y_test, y_pred, target_names=["importer", "exporter"])
  )
# Out:
#               precision    recall  f1-score   support
#
#     importer       0.66      0.55      0.60       220
#     exporter       0.60      0.70      0.65       212
#
#     accuracy                           0.63       432
#    macro avg       0.63      0.63      0.63       432
# weighted avg       0.63      0.63      0.63       432

# %%
from sklearn import metrics

y_pred_proba = clf.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)

plt.plot(fpr, tpr, label=("Logistic Regression, AUC=%.2f" % auc))
plt.axline((0, 0), slope=1, color="black", linestyle='--', alpha=0.5)

plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.title("ROC Performance")
plt.legend(loc="lower right")
plt.grid(zorder=0, linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# ![roc.png](data:image/png;base64,...)

# %% [markdown]
# "In general, an AUC of 0.5 suggests no discrimination (i.e., ability to diagnose patients with and without the disease or condition based on the test), 0.7 to 0.8 is considered acceptable, 0.8 to 0.9 is considered excellent, and more than 0.9 is considered outstanding." (DOI: [10.1097/JTO.0b013e3181ec173d](https://doi.org/10.1097/JTO.0b013e3181ec173d))

# %% [markdown]
# ## Section 2: Neural networks in PyTorch

# %%
print(dat_src.info(verbose=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21812 entries, 0 to 21811
# Data columns (total 129 columns):
#  #    Column                                        Dtype
# ---   ------                                        -----
#  0    country                                       object
#  1    year                                          int64
#  2    iso_code                                      object
#  3    population                                    float64
#  4    gdp                                           float64
#  5    biofuel_cons_change_pct                       float64
#  6    biofuel_cons_change_twh                       float64
#  7    biofuel_cons_per_capita                       float64
#  8    biofuel_consumption                           float64
#  9    biofuel_elec_per_capita                       float64
#  10   biofuel_electricity                           float64
#  11   biofuel_share_elec                            float64
#  12   biofuel_share_energy                          float64
#  13   carbon_intensity_elec                         float64
#  14   coal_cons_change_pct                          float64
#  15   coal_cons_change_twh                          float64
#  16   coal_cons_per_capita                          float64
#  17   coal_consumption                              float64
#  18   coal_elec_per_capita                          float64
#  19   coal_electricity                              float64
#  20   coal_prod_change_pct                          float64
#  21   coal_prod_change_twh                          float64
#  22   coal_prod_per_capita                          float64
#  23   coal_production                               float64
#  24   coal_share_elec                               float64
#  25   coal_share_energy                             float64
#  26   electricity_demand                            float64
#  27   electricity_generation                        float64
#  28   electricity_share_energy                      float64
#  29   energy_cons_change_pct                        float64
#  30   energy_cons_change_twh                        float64
#  31   energy_per_capita                             float64
#  32   energy_per_gdp                                float64
#  33   fossil_cons_change_pct                        float64
#  34   fossil_cons_change_twh                        float64
#  35   fossil_elec_per_capita                        float64
#  36   fossil_electricity                            float64
#  37   fossil_energy_per_capita                      float64
#  38   fossil_fuel_consumption                       float64
#  39   fossil_share_elec                             float64
#  40   fossil_share_energy                           float64
#  41   gas_cons_change_pct                           float64
#  42   gas_cons_change_twh                           float64
#  43   gas_consumption                               float64
#  44   gas_elec_per_capita                           float64
#  45   gas_electricity                               float64
#  46   gas_energy_per_capita                         float64
#  47   gas_prod_change_pct                           float64
#  48   gas_prod_change_twh                           float64
#  49   gas_prod_per_capita                           float64
#  50   gas_production                                float64
#  51   gas_share_elec                                float64
#  52   gas_share_energy                              float64
#  53   greenhouse_gas_emissions                      float64
#  54   hydro_cons_change_pct                         float64
#  55   hydro_cons_change_twh                         float64
#  56   hydro_consumption                             float64
#  57   hydro_elec_per_capita                         float64
#  58   hydro_electricity                             float64
#  59   hydro_energy_per_capita                       float64
#  60   hydro_share_elec                              float64
#  61   hydro_share_energy                            float64
#  62   low_carbon_cons_change_pct                    float64
#  63   low_carbon_cons_change_twh                    float64
#  64   low_carbon_consumption                        float64
#  65   low_carbon_elec_per_capita                    float64
#  66   low_carbon_electricity                        float64
#  67   low_carbon_energy_per_capita                  float64
#  68   low_carbon_share_elec                         float64
#  69   low_carbon_share_energy                       float64
#  70   net_elec_imports                              float64
#  71   net_elec_imports_share_demand                 float64
#  72   nuclear_cons_change_pct                       float64
#  73   nuclear_cons_change_twh                       float64
#  74   nuclear_consumption                           float64
#  75   nuclear_elec_per_capita                       float64
#  76   nuclear_electricity                           float64
#  77   nuclear_energy_per_capita                     float64
#  78   nuclear_share_elec                            float64
#  79   nuclear_share_energy                          float64
#  80   oil_cons_change_pct                           float64
#  81   oil_cons_change_twh                           float64
#  82   oil_consumption                               float64
#  83   oil_elec_per_capita                           float64
#  84   oil_electricity                               float64
#  85   oil_energy_per_capita                         float64
#  86   oil_prod_change_pct                           float64
#  87   oil_prod_change_twh                           float64
#  88   oil_prod_per_capita                           float64
#  89   oil_production                                float64
#  90   oil_share_elec                                float64
#  91   oil_share_energy                              float64
#  92   other_renewable_consumption                   float64
#  93   other_renewable_electricity                   float64
#  94   other_renewable_exc_biofuel_electricity       float64
#  95   other_renewables_cons_change_pct              float64
#  96   other_renewables_cons_change_twh              float64
#  97   other_renewables_elec_per_capita              float64
#  98   other_renewables_elec_per_capita_exc_biofuel  float64
#  99   other_renewables_energy_per_capita            float64
#  100  other_renewables_share_elec                   float64
#  101  other_renewables_share_elec_exc_biofuel       float64
#  102  other_renewables_share_energy                 float64
#  103  per_capita_electricity                        float64
#  104  primary_energy_consumption                    float64
#  105  renewables_cons_change_pct                    float64
#  106  renewables_cons_change_twh                    float64
#  107  renewables_consumption                        float64
#  108  renewables_elec_per_capita                    float64
#  109  renewables_electricity                        float64
#  110  renewables_energy_per_capita                  float64
#  111  renewables_share_elec                         float64
#  112  renewables_share_energy                       float64
#  113  solar_cons_change_pct                         float64
#  114  solar_cons_change_twh                         float64
#  115  solar_consumption                             float64
#  116  solar_elec_per_capita                         float64
#  117  solar_electricity                             float64
#  118  solar_energy_per_capita                       float64
#  119  solar_share_elec                              float64
#  120  solar_share_energy                            float64
#  121  wind_cons_change_pct                          float64
#  122  wind_cons_change_twh                          float64
#  123  wind_consumption                              float64
#  124  wind_elec_per_capita                          float64
#  125  wind_electricity                              float64
#  126  wind_energy_per_capita                        float64
#  127  wind_share_elec                               float64
#  128  wind_share_energy                             float64
# dtypes: float64(126), int64(1), object(2)
# memory usage: 21.5+ MB
# None

# %%
import os
import tqdm

import torch
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim

# %%
y = np.where(dat_src["net_elec_imports_share_demand"] > 0, 1, 0)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)
print(y.shape)

print(dat_src.shape)
X = dat_src.drop(columns=[
      "country",
      "year",
      "iso_code",
      "net_elec_imports_share_demand",
    ])
X = torch.tensor(X.to_numpy(), dtype=torch.float32)
X = torch.nan_to_num(X)
print(X.shape)
# Out:
# torch.Size([21812, 1])
# (21812, 129)
# torch.Size([21812, 125])

# %%
class MyNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.block1 = nn.Sequential(
            nn.Linear(125, 150),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(150, 150),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(150, 1),
        )
        self.sigmoid = nn.Sigmoid()

        for m in self.modules():
          if isinstance(m, nn.Linear):
            nn.init.kaiming_uniform_(m.weight, nonlinearity='relu')
            #nn.init.normal_(m.weight, mean=0.0, std=1.0)

    def forward(self, x):
        x = self.block1(x)
        x = self.sigmoid(x)
        return x

# %% [markdown]
# The training boilerplate function below courtesy of [Jason Brownlee](https://machinelearningmastery.com/building-a-binary-classification-model-in-pytorch/).

# %%
import copy

def model_train(model, X_train, y_train, X_val, y_val):
    # loss function and optimizer
    loss_fn = nn.BCELoss()  # binary cross entropy
    #loss_fn = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-6)

    n_epochs = 10 # number of epochs to run
    batch_size = 100 # size of each batch
    batch_start = torch.arange(0, len(X_train), batch_size)

    # Hold the best model
    best_acc = -np.inf   # init to negative infinity
    best_weights = None

    for epoch in range(n_epochs):
        model.train()
        with tqdm.tqdm(batch_start, unit="batch", mininterval=0, disable=False) as bar:
            bar.set_description(f"Epoch {epoch}")
            for start in bar:
                # take a batch
                X_batch = X_train[start:start+batch_size]
                y_batch = y_train[start:start+batch_size]
                # forward pass
                y_pred = model(X_batch)
                loss = loss_fn(y_pred, y_batch)
                # backward pass
                optimizer.zero_grad()
                loss.backward()
                # update weights
                optimizer.step()
                # print progress
                acc = (y_pred.round() == y_batch).float().mean()
                bar.set_postfix(
                    loss=float(loss),
                    acc=float(acc)
                )
        # evaluate accuracy at end of each epoch
        model.eval()
        y_pred = model(X_val)
        acc = (y_pred.round() == y_val).float().mean()
        acc = float(acc)
        if acc > best_acc:
            best_acc = acc
            best_weights = copy.deepcopy(model.state_dict())
    # restore model and return best accuracy
    model.load_state_dict(best_weights)
    return best_acc

# %%
from sklearn.model_selection import StratifiedKFold, train_test_split

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Training on {device}.\n")

model = MyNN()#.to(device)
print(model)

print("This model has %d parameters." % sum([x.reshape(-1).shape[0] for x in model.parameters()]))

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True)

acc = model_train(model, X_train, y_train, X_test, y_test)
print(f"Final model accuracy: {acc*100:.2f}%")
# Out:
# Training on cpu.
#
# MyNN(
#   (block1): Sequential(
#     (0): Linear(in_features=125, out_features=150, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=150, out_features=150, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=150, out_features=1, bias=True)
#   )
#   (sigmoid): Sigmoid()
# )
# This model has 41701 parameters.
# Epoch 0: 100%|██████████| 153/153 [00:03<00:00, 40.12batch/s, acc=0.618, loss=35.4]
# Epoch 1: 100%|██████████| 153/153 [00:04<00:00, 31.94batch/s, acc=0.706, loss=28]
# Epoch 2: 100%|██████████| 153/153 [00:03<00:00, 45.50batch/s, acc=0.588, loss=39.7]
# Epoch 3: 100%|██████████| 153/153 [00:03<00:00, 41.28batch/s, acc=0.471, loss=53]
# Epoch 4: 100%|██████████| 153/153 [00:03<00:00, 45.53batch/s, acc=0.603, loss=38.2]
# Epoch 5: 100%|██████████| 153/153 [00:03<00:00, 38.63batch/s, acc=0.647, loss=35.3]
# Epoch 6: 100%|██████████| 153/153 [00:04<00:00, 32.31batch/s, acc=0.647, loss=32.5]
# Epoch 7: 100%|██████████| 153/153 [00:02<00:00, 60.73batch/s, acc=0.662, loss=33.8]
# Epoch 8: 100%|██████████| 153/153 [00:01<00:00, 87.38batch/s, acc=0.618, loss=36.8]
# Epoch 9: 100%|██████████| 153/153 [00:01<00:00, 88.26batch/s, acc=0.632, loss=35.3]
# Final model accuracy: 60.80%

# %%
model.eval()
with torch.no_grad():
  p = model(X_test)
  y_pred_roc = p.squeeze(-1).detach().numpy()
  y_test_roc = y_test.squeeze(-1).detach().numpy()

  fpr_roc, tpr_roc, _ = metrics.roc_curve(y_test_roc, y_pred_roc)
  auc_roc = metrics.roc_auc_score(y_test_roc, y_pred_roc)
  plt.plot(fpr_roc, tpr_roc, label=("NN, AUC=%.2f" % auc_roc))

  plt.plot(fpr, tpr, label=("Logistic Regression, AUC=%.2f" % auc))
  plt.axline((0, 0), slope=1, color="black", linestyle='--', alpha=0.5)

  plt.xlabel("False Positive Rate (FPR)")
  plt.ylabel("True Positive Rate (TPR)")
  plt.title("ROC Performance")
  plt.legend(loc="lower right")
  plt.grid(zorder=0, linestyle='--', alpha=0.5)

  plt.show()
